# %%
#!pip install --ignore-installed --user ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/87/ac/fe69868ff03b9488504398018841edf9cd07bb77ce47aa32b1d13a8b52a5/ultralytics-8.2.22-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.7 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.7 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.7 kB 165.2 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/40.7 kB 187.9 kB/s eta 0:00:01
#      -------------------------------------- 40.7/40.7 kB 162.9 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for matplotlib>=3.3.0 from https://files.pythonhosted.org/packages/c6/c8/6936e8c7b279a5abac82f399d8d72ac25da530cf5f78a0e40063e492558c/matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
#!pip install --ignore-installed --user torch
# Out:
# ...
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/2a/b7/a3cf5fd40334b9785cc83ee0c96b50603026eb3aa70210a33729018e7029/torch-2.3.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.3.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# ...
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/41/24/0b023b6537dfc9bae2c779353998e3e99ac7dfff4222fc6126650e93c3f3/filelock-3.14.0-py3-none-any.whl.metadata
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/e1/4d/d612de852a0bc64a64418e1cef25fe1914c5b1611e34cc271ed7e36174c8/typing_extensions-4.12.0-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.12.0-py3-none-any.whl.metadata (3.0 kB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)

model.train(data='./data_species',
            epochs=40, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.2.26 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.22  Python-3.11.5 torch-2.3.0+cpu CPU (Intel Core(TM) i7-9750H 2.60GHz)
# ...

# %%
metrics = model.val()  # no arguments needed, dataset and settings remembered
# Out:
# Ultralytics YOLOv8.2.22  Python-3.11.5 torch-2.3.0+cpu CPU (Intel Core(TM) i7-9750H 2.60GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1442566 parameters, 0 gradients, 3.3 GFLOPs
# train: C:\Users\marti\OneDrive\Martin OneDrive\ISEP\A2\Semestre 2\Ai and optimisation\Projet\train\Test 23-05-2024\data\train... found 337 images in 6 classes
# val: C:\Users\marti\OneDrive\Martin OneDrive\ISEP\A2\Semestre 2\Ai and optimisation\Projet\train\Test 23-05-2024\data\val... found 65 images in 6 classes
# test: None...
# val: Scanning C:\Users\marti\OneDrive\Martin OneDrive\ISEP\A2\Semestre 2\Ai and optimisation\Projet\train\Test 23-05-2024\data\val... 65 images, 0 corrupt: 100%|██████████| 65/65 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:09<00:00,  1.99s/it]
#                    all      0.938          1
# Speed: 0.0ms preprocess, 72.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\train82

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_path = './runs/classify/train7/results.csv'

results = pd.read_csv(results_path)

results
# Out:
#                     epoch             train/loss  metrics/accuracy_top1  \
# 0                       1                1.69560                0.36923
# 1                       2                1.40160                0.46154
# 2                       3                1.00330                0.61538
# 3                       4                0.67384                0.80000
# 4                       5                0.45391                0.84615
# 5                       6                0.27213                0.83077
# 6                       7                0.29915                0.81538
# 7                       8                0.21325                0.87692
# 8                       9                0.11815                0.92308
# 9                      10                0.19097                0.80000
# 10                     11                0.19119                0.92308
# 11                     12                0.10749                0.92308
# ...

# %%
from ultralytics import YOLO

import numpy as np


model = YOLO('./runs/classify/train7/weights/last.pt')  # load a custom model

results = model('./Test_IV2/Bumbleb/218.JPG')  # predict on an image

names_dict = results[0].names

probs = results[0].probs.data.tolist()

print(names_dict)
print(probs)

print(names_dict[np.argmax(probs)])
# Out:
# image 1/1 C:\Users\marti\OneDrive\Martin OneDrive\ISEP\A2\Semestre 2\Ai and optimisation\Projet\train\Test 23-05-2024\Test_IV2\Bumblebee\218.JPG: 64x64 Bumblebee 0.90, Hover fly 0.06, Bee 0.02, Wasp 0.01, Dragonfly 0.01, 8.0ms
# Speed: 18.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
# {0: 'Bee', 1: 'Bumblebee', 2: 'Butterfly', 3: 'Dragonfly', 4: 'Hover fly', 5: 'Wasp'}
# [0.016254108399152756, 0.9049656391143799, 0.0031011481769382954, 0.006512462627142668, 0.055731479078531265, 0.013435235247015953]
# Bumblebee

# %%
model = YOLO('./runs/classify/train5/weights/last.pt')  # load a custom model

metrics = model.val()  # no arguments needed, dataset and settings remembered
# Out:
# Ultralytics YOLOv8.2.22  Python-3.11.5 torch-2.3.0+cpu CPU (Intel Core(TM) i7-9750H 2.60GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1442566 parameters, 0 gradients, 3.3 GFLOPs
# train: C:\Users\marti\OneDrive\Martin OneDrive\ISEP\A2\Semestre 2\Ai and optimisation\Projet\train\Test 23-05-2024\data\train... found 337 images in 6 classes
# val: C:\Users\marti\OneDrive\Martin OneDrive\ISEP\A2\Semestre 2\Ai and optimisation\Projet\train\Test 23-05-2024\data\val... found 65 images in 6 classes
# test: None...
# val: Scanning C:\Users\marti\OneDrive\Martin OneDrive\ISEP\A2\Semestre 2\Ai and optimisation\Projet\train\Test 23-05-2024\data\val... 65 images, 0 corrupt: 100%|██████████| 65/65 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,  1.53s/it]
#                    all      0.923          1
# Speed: 0.0ms preprocess, 49.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\val3
